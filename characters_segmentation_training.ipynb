# %%
import os
import shutil

# %%
train_dir='/content/drive/MyDrive/symbol_segmentation/train/'
val_dir='/content/drive/MyDrive/symbol_segmentation/valid/'
test_dir='/content/drive/MyDrive/segmentation/test/'

# %%
print(len([name for name in os.listdir(train_dir+'labels')]))
# Out:
# 422

# %%
print(len([name for name in os.listdir(val_dir+'labels')]))
# Out:
# 50

# %%
with open(f"/content/characters_segmentation.yaml", "w+") as file_:
  file_.write(
           f"""
           train: {train_dir}
           val: {val_dir}
           test:  # test images (optional)
           nc: 1
           names: ["letter"]

            """
)

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# Out:
# Resolving deltas: 100% (10962/10962), done.

# %%
# !pip install -r /content/yolov5/requirements.txt

# %%
# !python /content/yolov5/train.py --img 360 --batch 32 --epochs 150 --data /content/characters_segmentation.yaml --weights 'yolov5m.pt' --cache
# Out:
# train: weights=yolov5m.pt, cfg=, data=/content/characters_segmentation.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=150, batch_size=32, imgsz=360, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=yolov5/runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-177-g89c3040 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
# !zip -r /content/yolov5/runs/train/exp.zip  /content/yolov5/runs/train/exp

# %%
# !python /content/yolov5/train.py --img 360 --batch 32 --epochs 150 --data /content/characters_segmentation.yaml --cfg /content/yolov5/models/hub/yolov5s-transformer.yaml --cache
# Out:
# train: weights=yolov5/yolov5s.pt, cfg=/content/yolov5/models/hub/yolov5s-transformer.yaml, data=/content/characters_segmentation.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=150, batch_size=32, imgsz=360, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=yolov5/runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-177-g89c3040 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
# !zip -r /content/yolov5/runs/train/exp2.zip  /content/yolov5/runs/train/exp2
# Out:
#   adding: content/yolov5/runs/train/exp2/ (stored 0%)
#   adding: content/yolov5/runs/train/exp2/train_batch2.jpg (deflated 2%)
#   adding: content/yolov5/runs/train/exp2/val_batch0_pred.jpg (deflated 11%)
#   adding: content/yolov5/runs/train/exp2/weights/ (stored 0%)
#   adding: content/yolov5/runs/train/exp2/weights/.ipynb_checkpoints/ (stored 0%)
#   adding: content/yolov5/runs/train/exp2/opt.yaml (deflated 49%)
#   adding: content/yolov5/runs/train/exp2/confusion_matrix.png (deflated 42%)
#   adding: content/yolov5/runs/train/exp2/hyp.yaml (deflated 45%)
#   adding: content/yolov5/runs/train/exp2/train_batch0.jpg (deflated 3%)
#   adding: content/yolov5/runs/train/exp2/P_curve.png (deflated 23%)
#   adding: content/yolov5/runs/train/exp2/R_curve.png (deflated 19%)
#   adding: content/yolov5/runs/train/exp2/results.png (deflated 10%)
#   adding: content/yolov5/runs/train/exp2/F1_curve.png (deflated 18%)
#   adding: content/yolov5/runs/train/exp2/train_batch1.jpg (deflated 3%)
# ...

# %%
# !python /content/yolov5/train.py --img 360 --batch 32 --epochs 150 --data /content/characters_segmentation.yaml --weight 'yolov5x.pt' --cache
# Out:
# train: weights=yolov5x.pt, cfg=, data=/content/characters_segmentation.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=150, batch_size=32, imgsz=360, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=yolov5/runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-177-g89c3040 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
# !python /content/yolov5/train.py --img 360 --batch 32 --epochs 150 --data /content/characters_segmentation.yaml --weight 'yolov5s.pt' --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=/content/characters_segmentation.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=150, batch_size=32, imgsz=360, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=yolov5/runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-177-g89c3040 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
# !zip -r /content/yolov5/runs/train/exp3.zip  /content/yolov5/runs/train/exp3
# Out:
#   adding: content/yolov5/runs/train/exp3/ (stored 0%)
#   adding: content/yolov5/runs/train/exp3/train_batch2.jpg (deflated 2%)
#   adding: content/yolov5/runs/train/exp3/val_batch0_pred.jpg (deflated 11%)
#   adding: content/yolov5/runs/train/exp3/weights/ (stored 0%)
#   adding: content/yolov5/runs/train/exp3/weights/.ipynb_checkpoints/ (stored 0%)
#   adding: content/yolov5/runs/train/exp3/opt.yaml (deflated 49%)
#   adding: content/yolov5/runs/train/exp3/confusion_matrix.png (deflated 42%)
#   adding: content/yolov5/runs/train/exp3/hyp.yaml (deflated 45%)
#   adding: content/yolov5/runs/train/exp3/train_batch0.jpg (deflated 3%)
#   adding: content/yolov5/runs/train/exp3/P_curve.png (deflated 23%)
#   adding: content/yolov5/runs/train/exp3/R_curve.png (deflated 20%)
#   adding: content/yolov5/runs/train/exp3/results.png (deflated 11%)
#   adding: content/yolov5/runs/train/exp3/F1_curve.png (deflated 18%)
#   adding: content/yolov5/runs/train/exp3/train_batch1.jpg (deflated 3%)
# ...

# %%
# !mv /content/yolov5/runs/train/exp /content/drive/MyDrive/symbol_segmentation
